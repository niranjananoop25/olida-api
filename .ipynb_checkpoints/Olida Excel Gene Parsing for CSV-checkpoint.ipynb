# %% [markdown]
# # Download OLIDA Excel files into jupyter notebook data folder
# On OLIDA website, download Excel files of "Genes", "Diseases", and "Gene Combinations" and upload to a data folder in jupyter notebook

# %% [markdown]
# # Import modules

# %%
import pandas as pd

# %% [markdown]
# # Get Excel data

# %%
# Get gene data
df_gene = pd.read_excel('data/Gene.xlsx', skiprows=1)

# Get disease data
df_disease = pd.read_excel('data/Disease.xlsx', skiprows=1)

#Get gene combo data
df_combo = pd.read_excel('data/GeneCombination.xlsx', skiprows=1)

# %%
df_gene
# Out:
#      Gene Name       Ensembl Id        Entrez Id Chromosome  \
# 0       ABCA13  ENSG00000179869           154664          7
# 1        ABCA7  ENSG00000064687            10347         19
# 2        ABCC6  ENSG00000091262              368         16
# 3        ABCC8  ENSG00000006071             6833         11
# 4        ABCC9  ENSG00000069431            10060         12
# ...        ...              ...              ...        ...
# 1070    ZNF205  ENSG00000122386             7755         16
# 1071    ZNF263  ENSG00000006194            10127         16
# 1072    ZNF408              NaN  ENSG00000175213         11
# 1073     ZNFX1              NaN  ENSG00000124201         20
# 1074     ZNRF3              NaN  ENSG00000183579         22
#
#      Uniprot Accession Number  \
# 0                  A0A0A0MT16
# 1                      Q8IZY2
# 2                      O95255
# 3                      Q09428
# 4                      O60706
# ...                       ...
# 1070                   O95201
# 1071                   O14978
# 1072                   Q9H9D4
# 1073                   Q9P2E3
# 1074                   Q9ULT6
#
#                        Gene Ontology Molecular Function Essential In Mouse  \
# 0     ATPase-coupled transmembrane transporter activ...               N.A.
# 1     apolipoprotein A-I receptor activity; phosphat...      Non-essential
# 2     transporter activity; transmembrane transporte...      Non-essential
# 3     ATP-activated inward rectifier potassium chann...      Non-essential
# 4     ATPase-coupled cation transmembrane transporte...      Non-essential
# ...                                                 ...                ...
# 1070  protein binding; DNA-binding transcription fac...               N.A.
# 1071  protein binding; DNA-binding transcription fac...               N.A.
# 1072  ['RNA polymerase II cis-regulatory region sequ...               N.A.
# 1073  ['helicase activity', 'zinc ion binding', 'RNA...               N.A.
# 1074  ['ubiquitin-protein transferase activity', 'fr...               N.A.
#
#                                                 Pathway  \
# 0     hsa02010; R-HSA-168249; R-HSA-168256; hsa02010...
# 1     hsa02010; R-HSA-1369062; R-HSA-382556; R-HSA-3...
# 2     R-HSA-5619115; R-HSA-382551; R-HSA-5619084; R-...
# 3     R-HSA-1430728; R-HSA-1296025; R-HSA-5619084; R...
# 4     R-HSA-1296065; R-HSA-5678420; R-HSA-5619115; R...
# ...                                                 ...
# 1070   R-HSA-74160; R-HSA-73857; hsa05168; R-HSA-212436
# 1071             R-HSA-74160; R-HSA-73857; R-HSA-212436
# 1072                                               N.A.
# 1073                                               N.A.
# 1074  hsa04310; R-HSA-162582; R-HSA-195721; R-HSA-20...
#
#                                                Variants  \
# 0                       ABCA13:c.13662G>A, p.Met4554Ile
# 1     ABCA7:c.5092C>T, p.Arg1698Trp; ABCA7:c.3076C>T...
# 2                                    ABCC6:p.Arg1141Ter
# 3     ABCC8:c.3976G>A, p.Glu1326Lys; ABCC8:c.3394G>A...
# 4                         ABCC9:c.3594G>A, p.Met1198Ile
# ...                                                 ...
# 1070                       ZNF205:c.925C>T, p.Arg309Trp
# 1071                       ZNF263:c.653G>T, p.Ser218Ile
# 1072  ZNF408:c.892G>A, p.Gly298Ser; ZNF408:c.1964G>C...
# 1073                                     ZNFX1:c.2302,
# 1074  ZNRF3:c.1278C>G, p.His426Gln; ZNRF3:c.766G>A, ...
#
#                                            Combinations  \
# 0                                                OLI935
# 1                                OLI788; OLI799; OLI787
# 2                                                OLI301
# 3                                        OLI005; OLI004
# 4                                                OLI232
# ...                                                 ...
# 1070                                            OLI1142
# 1071                                            OLI1139
# 1072  OLI313; OLI1259; OLI1256; OLI1250; OLI1254; OL...
# 1073                                            OLI1329
# 1074  OLI711; OLI1539; OLI1526; OLI705; OLI1531; OLI...
#
#                                                Diseases
# 0                                         Schizophrenia
# 1                               Arthrogryposis syndrome
# 2                              Pseudoxanthoma elasticum
# 3     Pulmonary arterial hypertension associated wit...
# 4     Left ventricular noncompaction; Rubinstein-Tay...
# ...                                                 ...
# 1070            Mayer-Rokitansky-Küster-Hauser syndrome
# 1071            Mayer-Rokitansky-Küster-Hauser syndrome
# 1072               Familial exudative vitreoretinopathy
# 1073                           Primary immunodeficiency
# 1074  Isolated anencephaly; 46,XY disorder of sex de...
#
# [1075 rows x 11 columns]

# %%
df_gene['Combinations'] = df_gene['Combinations'].str.replace(';','').apply(str.split)
df_gene['Combinations']
# Out:
# 0                                                [OLI935]
# 1                                [OLI788, OLI799, OLI787]
# 2                                                [OLI301]
# 3                                        [OLI005, OLI004]
# 4                                                [OLI232]
#                               ...
# 1070                                            [OLI1142]
# 1071                                            [OLI1139]
# 1072    [OLI313, OLI1259, OLI1256, OLI1250, OLI1254, O...
# 1073                                            [OLI1329]
# 1074    [OLI711, OLI1539, OLI1526, OLI705, OLI1531, OL...
# Name: Combinations, Length: 1075, dtype: object

# %%
df_gene['Combinations'] = df_gene['Combinations'].str.split(';')

# %%
df_gene = df_gene.explode('Combinations')

# %%
df_gene.sort_values(by='Combinations')
# Out:
#      Gene Name       Ensembl Id        Entrez Id Chromosome  \
# 670     NOTCH3  ENSG00000074181             4854         19
# 105      BMPR2  ENSG00000204217              659          2
# 670     NOTCH3  ENSG00000074181             4854         19
# 3        ABCC8  ENSG00000006071             6833         11
# 969        TEK  ENSG00000120156             7010          9
# ...        ...              ...              ...        ...
# 1016      TSHR              NaN  ENSG00000165409         14
# 339      FKBP4  ENSG00000004478             2288         12
# 237       DGKK  ENSG00000274588           139189          X
# 103       BMP4              NaN  ENSG00000125378         14
# 619       MYH6  ENSG00000197616             4624         14
#
#      Uniprot Accession Number  \
# 670                    Q9UM47
# 105                    Q13873
# 670                    Q9UM47
# 3                      Q09428
# 969                    Q02763
# ...                       ...
# 1016               A0A0A0MTJ0
# 339                    Q02790
# 237                    Q5KSL6
# 103                    P12644
# 619                    P13533
#
#                        Gene Ontology Molecular Function Essential In Mouse  \
# 670   calcium ion binding; protein binding; enzyme b...      Non-essential
# 105   BMP receptor activity; protein binding; cadher...          Essential
# 670   calcium ion binding; protein binding; enzyme b...      Non-essential
# 3     ATP-activated inward rectifier potassium chann...      Non-essential
# 969                                     protein binding          Essential
# ...                                                 ...                ...
# 1016  ['signaling receptor activity', 'thyroid-stimu...          Essential
# 339   GTP binding; FK506 binding; protein binding; p...          Essential
# 237   metal ion binding; NAD+ kinase activity; diacy...               N.A.
# 103   ['growth factor activity', 'BMP receptor bindi...          Essential
# 619   protein kinase binding; ATP binding; actin fil...          Essential
#
#                                                 Pathway  \
# 670   hsa05200; R-HSA-350054; R-HSA-74160; R-HSA-901...
# 105   hsa04060; hsa05418; hsa04350; R-HSA-162582; R-...
# 670   hsa05200; R-HSA-350054; R-HSA-74160; R-HSA-901...
# 3     R-HSA-1430728; R-HSA-1296025; R-HSA-5619084; R...
# 969   hsa05323; R-HSA-162582; hsa04010; R-HSA-202733...
# ...                                                 ...
# 1016  hsa04024; hsa04080; hsa04918; hsa04923; hsa053...
# 339   R-HSA-162582; R-HSA-9679191; hsa04915; R-HSA-8...
# 237   R-HSA-76002; hsa04070; hsa00561; R-HSA-109582;...
# 103   hsa04060; hsa04350; hsa04390; hsa04550; hsa049...
# 619   hsa04261; hsa05414; hsa04919; R-HSA-390522; hs...
#
#                                                Variants Combinations  \
# 670   NOTCH3:c.181C>T, p.Arg61Trp; NOTCH3:c.1964A>G,...       OLI002
# 105   Copy Number Variant duplication on chromosome ...       OLI002
# 670   NOTCH3:c.181C>T, p.Arg61Trp; NOTCH3:c.1964A>G,...       OLI004
# 3     ABCC8:c.3976G>A, p.Glu1326Lys; ABCC8:c.3394G>A...       OLI004
# 969   TEK:p.Glu103Asp; TEK:p.Ile148Thr; TEK:p.Gln214...       OLI009
# ...                                                 ...          ...
# 1016  TSHR:p.Cys176Arg; TSHR:p.Lys618Ter; TSHR:c.151...       OLI987
# 339                        FKBP4:c.1066C>T, p.Leu356Phe       OLI996
# 237                          DGKK:c.316G>A, p.Ala106Thr       OLI996
# 103   BMP4:c.794G>A, p.Trp265Ter; BMP4:p.Asn150Lys; ...       OLI997
# 619                 MYH6:; MYH6:c.4231G>A, p.Ala1411Thr       OLI998
#
#                                                Diseases
# 670   Primary ovarian failure; Idiopathic pulmonary ...
# 105   Pulmonary arterial hypertension; Heritable pul...
# 670   Primary ovarian failure; Idiopathic pulmonary ...
# 3     Pulmonary arterial hypertension associated wit...
# 969                                 Congenital glaucoma
# ...                                                 ...
# 1016                          Congenital hypothyroidism
# 339   Androgen insensitivity syndrome; 46,XY disorde...
# 237   Androgen insensitivity syndrome; 46,XY disorde...
# 103   Androgen insensitivity syndrome; Non-acquired ...
# 619   Hypertrophic cardiomyopathy; Androgen insensit...
#
# [3866 rows x 11 columns]

# %%
df_gene['Combinations'] = df_gene['Combinations'].str.split(';')
# Out:
#      Gene Name       Ensembl Id        Entrez Id Chromosome  \
# 0       ABCA13  ENSG00000179869           154664          7
# 1        ABCA7  ENSG00000064687            10347         19
# 2        ABCC6  ENSG00000091262              368         16
# 3        ABCC8  ENSG00000006071             6833         11
# 4        ABCC9  ENSG00000069431            10060         12
# ...        ...              ...              ...        ...
# 1070    ZNF205  ENSG00000122386             7755         16
# 1071    ZNF263  ENSG00000006194            10127         16
# 1072    ZNF408              NaN  ENSG00000175213         11
# 1073     ZNFX1              NaN  ENSG00000124201         20
# 1074     ZNRF3              NaN  ENSG00000183579         22
#
#      Uniprot Accession Number  \
# 0                  A0A0A0MT16
# 1                      Q8IZY2
# 2                      O95255
# 3                      Q09428
# 4                      O60706
# ...                       ...
# 1070                   O95201
# 1071                   O14978
# 1072                   Q9H9D4
# 1073                   Q9P2E3
# 1074                   Q9ULT6
#
#                        Gene Ontology Molecular Function Essential In Mouse  \
# 0     ATPase-coupled transmembrane transporter activ...               N.A.
# 1     apolipoprotein A-I receptor activity; phosphat...      Non-essential
# 2     transporter activity; transmembrane transporte...      Non-essential
# 3     ATP-activated inward rectifier potassium chann...      Non-essential
# 4     ATPase-coupled cation transmembrane transporte...      Non-essential
# ...                                                 ...                ...
# 1070  protein binding; DNA-binding transcription fac...               N.A.
# 1071  protein binding; DNA-binding transcription fac...               N.A.
# 1072  ['RNA polymerase II cis-regulatory region sequ...               N.A.
# 1073  ['helicase activity', 'zinc ion binding', 'RNA...               N.A.
# 1074  ['ubiquitin-protein transferase activity', 'fr...               N.A.
#
#                                                 Pathway  \
# 0     hsa02010; R-HSA-168249; R-HSA-168256; hsa02010...
# 1     hsa02010; R-HSA-1369062; R-HSA-382556; R-HSA-3...
# 2     R-HSA-5619115; R-HSA-382551; R-HSA-5619084; R-...
# 3     R-HSA-1430728; R-HSA-1296025; R-HSA-5619084; R...
# 4     R-HSA-1296065; R-HSA-5678420; R-HSA-5619115; R...
# ...                                                 ...
# 1070   R-HSA-74160; R-HSA-73857; hsa05168; R-HSA-212436
# 1071             R-HSA-74160; R-HSA-73857; R-HSA-212436
# 1072                                               N.A.
# 1073                                               N.A.
# 1074  hsa04310; R-HSA-162582; R-HSA-195721; R-HSA-20...
#
#                                                Variants  \
# 0                       ABCA13:c.13662G>A, p.Met4554Ile
# 1     ABCA7:c.5092C>T, p.Arg1698Trp; ABCA7:c.3076C>T...
# 2                                    ABCC6:p.Arg1141Ter
# 3     ABCC8:c.3976G>A, p.Glu1326Lys; ABCC8:c.3394G>A...
# 4                         ABCC9:c.3594G>A, p.Met1198Ile
# ...                                                 ...
# 1070                       ZNF205:c.925C>T, p.Arg309Trp
# 1071                       ZNF263:c.653G>T, p.Ser218Ile
# 1072  ZNF408:c.892G>A, p.Gly298Ser; ZNF408:c.1964G>C...
# 1073                                     ZNFX1:c.2302,
# 1074  ZNRF3:c.1278C>G, p.His426Gln; ZNRF3:c.766G>A, ...
#
#                                            Combinations  \
# 0                                              [OLI935]
# 1                            [OLI788,  OLI799,  OLI787]
# 2                                              [OLI301]
# 3                                     [OLI005,  OLI004]
# 4                                              [OLI232]
# ...                                                 ...
# 1070                                          [OLI1142]
# 1071                                          [OLI1139]
# 1072  [OLI313,  OLI1259,  OLI1256,  OLI1250,  OLI125...
# 1073                                          [OLI1329]
# 1074  [OLI711,  OLI1539,  OLI1526,  OLI705,  OLI1531...
#
#                                                Diseases
# 0                                         Schizophrenia
# 1                               Arthrogryposis syndrome
# 2                              Pseudoxanthoma elasticum
# 3     Pulmonary arterial hypertension associated wit...
# 4     Left ventricular noncompaction; Rubinstein-Tay...
# ...                                                 ...
# 1070            Mayer-Rokitansky-Küster-Hauser syndrome
# 1071            Mayer-Rokitansky-Küster-Hauser syndrome
# 1072               Familial exudative vitreoretinopathy
# 1073                           Primary immunodeficiency
# 1074  Isolated anencephaly; 46,XY disorder of sex de...
#
# [1075 rows x 11 columns]

# %%
df_gene['Combinations']
# Out:
# 0                                                [OLI935]
# 1                              [OLI788,  OLI799,  OLI787]
# 2                                                [OLI301]
# 3                                       [OLI005,  OLI004]
# 4                                                [OLI232]
#                               ...
# 1070                                            [OLI1142]
# 1071                                            [OLI1139]
# 1072    [OLI313,  OLI1259,  OLI1256,  OLI1250,  OLI125...
# 1073                                            [OLI1329]
# 1074    [OLI711,  OLI1539,  OLI1526,  OLI705,  OLI1531...
# Name: Combinations, Length: 1075, dtype: object

# %%
df_gene=df_gene.explode('Combinations')

# %%
df_gene.sort_values(by='Combinations')
# Out:
#      Gene Name       Ensembl Id        Entrez Id Chromosome  \
# 670     NOTCH3  ENSG00000074181             4854         19
# 105      BMPR2  ENSG00000204217              659          2
# 670     NOTCH3  ENSG00000074181             4854         19
# 3        ABCC8  ENSG00000006071             6833         11
# 969        TEK  ENSG00000120156             7010          9
# ...        ...              ...              ...        ...
# 1016      TSHR              NaN  ENSG00000165409         14
# 339      FKBP4  ENSG00000004478             2288         12
# 237       DGKK  ENSG00000274588           139189          X
# 103       BMP4              NaN  ENSG00000125378         14
# 619       MYH6  ENSG00000197616             4624         14
#
#      Uniprot Accession Number  \
# 670                    Q9UM47
# 105                    Q13873
# 670                    Q9UM47
# 3                      Q09428
# 969                    Q02763
# ...                       ...
# 1016               A0A0A0MTJ0
# 339                    Q02790
# 237                    Q5KSL6
# 103                    P12644
# 619                    P13533
#
#                        Gene Ontology Molecular Function Essential In Mouse  \
# 670   calcium ion binding; protein binding; enzyme b...      Non-essential
# 105   BMP receptor activity; protein binding; cadher...          Essential
# 670   calcium ion binding; protein binding; enzyme b...      Non-essential
# 3     ATP-activated inward rectifier potassium chann...      Non-essential
# 969                                     protein binding          Essential
# ...                                                 ...                ...
# 1016  ['signaling receptor activity', 'thyroid-stimu...          Essential
# 339   GTP binding; FK506 binding; protein binding; p...          Essential
# 237   metal ion binding; NAD+ kinase activity; diacy...               N.A.
# 103   ['growth factor activity', 'BMP receptor bindi...          Essential
# 619   protein kinase binding; ATP binding; actin fil...          Essential
#
#                                                 Pathway  \
# 670   hsa05200; R-HSA-350054; R-HSA-74160; R-HSA-901...
# 105   hsa04060; hsa05418; hsa04350; R-HSA-162582; R-...
# 670   hsa05200; R-HSA-350054; R-HSA-74160; R-HSA-901...
# 3     R-HSA-1430728; R-HSA-1296025; R-HSA-5619084; R...
# 969   hsa05323; R-HSA-162582; hsa04010; R-HSA-202733...
# ...                                                 ...
# 1016  hsa04024; hsa04080; hsa04918; hsa04923; hsa053...
# 339   R-HSA-162582; R-HSA-9679191; hsa04915; R-HSA-8...
# 237   R-HSA-76002; hsa04070; hsa00561; R-HSA-109582;...
# 103   hsa04060; hsa04350; hsa04390; hsa04550; hsa049...
# 619   hsa04261; hsa05414; hsa04919; R-HSA-390522; hs...
#
#                                                Variants Combinations  \
# 670   NOTCH3:c.181C>T, p.Arg61Trp; NOTCH3:c.1964A>G,...       OLI002
# 105   Copy Number Variant duplication on chromosome ...       OLI002
# 670   NOTCH3:c.181C>T, p.Arg61Trp; NOTCH3:c.1964A>G,...       OLI004
# 3     ABCC8:c.3976G>A, p.Glu1326Lys; ABCC8:c.3394G>A...       OLI004
# 969   TEK:p.Glu103Asp; TEK:p.Ile148Thr; TEK:p.Gln214...       OLI009
# ...                                                 ...          ...
# 1016  TSHR:p.Cys176Arg; TSHR:p.Lys618Ter; TSHR:c.151...       OLI987
# 339                        FKBP4:c.1066C>T, p.Leu356Phe       OLI996
# 237                          DGKK:c.316G>A, p.Ala106Thr       OLI996
# 103   BMP4:c.794G>A, p.Trp265Ter; BMP4:p.Asn150Lys; ...       OLI997
# 619                 MYH6:; MYH6:c.4231G>A, p.Ala1411Thr       OLI998
#
#                                                Diseases
# 670   Primary ovarian failure; Idiopathic pulmonary ...
# 105   Pulmonary arterial hypertension; Heritable pul...
# 670   Primary ovarian failure; Idiopathic pulmonary ...
# 3     Pulmonary arterial hypertension associated wit...
# 969                                 Congenital glaucoma
# ...                                                 ...
# 1016                          Congenital hypothyroidism
# 339   Androgen insensitivity syndrome; 46,XY disorde...
# 237   Androgen insensitivity syndrome; 46,XY disorde...
# 103   Androgen insensitivity syndrome; Non-acquired ...
# 619   Hypertrophic cardiomyopathy; Androgen insensit...
#
# [3866 rows x 11 columns]

# %% [markdown]
# # Prepare dataframes

# %%
#Rename columns for exploding and merging
df_combo.rename(columns = {'Oligogenic variant combinations':'Combinations'}, inplace = True)
df_disease.rename(columns = {'Disease Name':'Diseases'}, inplace = True)

# Drop unwanted series
df_gene.drop(columns=['Ensembl Id', 'Entrez Id', 'Chromosome', 'Uniprot Accession Number', 'Gene Ontology Molecular Function', 'Essential In Mouse', 'Pathway', 'Variants'], inplace=True)
df_disease.drop(columns = ['Orphanet ID', 'ICD-10 Category', 'Omim Id'], inplace=True)
df_combo.drop(columns=['Entry Id', 'Genes Relationship', 'Protein Interactions', 'Common Pathways', 'Common Pathways', 'GENEmeta'], inplace=True)

# %% [markdown]
# # Define function

# %%
df_gene["Combinations"] = df_gene.Combinations.str.split(";")
df_gene = df_gene.explode("Combinations")

# %%
df_disease["Combinations"] = df_disease.Combinations.str.split(";")
df_disease = df_disease.explode("Combinations")

# %%
df_gene
# Out:
#      Gene Name Combinations                                           Diseases
# 0       ABCA13       OLI935                                      Schizophrenia
# 1        ABCA7       OLI788                            Arthrogryposis syndrome
# 1        ABCA7       OLI799                            Arthrogryposis syndrome
# 1        ABCA7       OLI787                            Arthrogryposis syndrome
# 2        ABCC6       OLI301                           Pseudoxanthoma elasticum
# ...        ...          ...                                                ...
# 1074     ZNRF3      OLI1526  Isolated anencephaly; 46,XY disorder of sex de...
# 1074     ZNRF3       OLI705  Isolated anencephaly; 46,XY disorder of sex de...
# 1074     ZNRF3      OLI1531  Isolated anencephaly; 46,XY disorder of sex de...
# 1074     ZNRF3       OLI744  Isolated anencephaly; 46,XY disorder of sex de...
# 1074     ZNRF3       OLI756  Isolated anencephaly; 46,XY disorder of sex de...
#
# [3866 rows x 3 columns]

# %%
df_gene.merge(df_disease, on=["Combinations", "Diseases"], how="left")
# Out:
#      Gene Name Combinations  \
# 0       ABCA13       OLI935
# 1        ABCA7       OLI788
# 2        ABCA7       OLI799
# 3        ABCA7       OLI787
# 4        ABCC6       OLI301
# ...        ...          ...
# 3861     ZNRF3      OLI1526
# 3862     ZNRF3       OLI705
# 3863     ZNRF3      OLI1531
# 3864     ZNRF3       OLI744
# 3865     ZNRF3       OLI756
#
#                                                Diseases ICD-10 ID
# 0                                         Schizophrenia       NaN
# 1                               Arthrogryposis syndrome       NaN
# 2                               Arthrogryposis syndrome     Q68.8
# 3                               Arthrogryposis syndrome       NaN
# 4                              Pseudoxanthoma elasticum     Q82.8
# ...                                                 ...       ...
# 3861  Isolated anencephaly; 46,XY disorder of sex de...       NaN
# 3862  Isolated anencephaly; 46,XY disorder of sex de...       NaN
# 3863  Isolated anencephaly; 46,XY disorder of sex de...       NaN
# 3864  Isolated anencephaly; 46,XY disorder of sex de...       NaN
# 3865  Isolated anencephaly; 46,XY disorder of sex de...       NaN
#
# [3866 rows x 4 columns]

# %%
df_disease
# Out:
#                                           Disease Name ICD-10 ID Combinations
# 0                          Duchenne muscular dystrophy      N.A.      OLI1480
# 1                                       Wilson disease      N.A.      OLI1480
# 2    Hypogonadotropic hypogonadism with absent pube...     E23.0      OLI1396
# 2    Hypogonadotropic hypogonadism with absent pube...     E23.0      OLI1397
# 2    Hypogonadotropic hypogonadism with absent pube...     E23.0      OLI1398
# ..                                                 ...       ...          ...
# 205                               Isolated anencephaly      N.A.       OLI762
# 205                               Isolated anencephaly      N.A.       OLI763
# 206  Non-syndromic metopic and sagittal craniosynos...      N.A.      OLI1358
# 206  Non-syndromic metopic and sagittal craniosynos...      N.A.      OLI1359
# 206  Non-syndromic metopic and sagittal craniosynos...      N.A.      OLI1368
#
# [1671 rows x 3 columns]

# %%
#Make combos in series into lists then explode
def combo_explode(df):
#     df['Combinations'] = df['Combinations'].str.split(";")
    df['Combinations'] = df['Combinations'].str.replace(';', '').apply(str.split)
    newdf = df.explode('Combinations')
    return newdf.sort_values("Combinations")

# %% [markdown]
#  # Execute functions

# %%
df_gene = combo_explode(df_gene)
df_disease = combo_explode(df_disease)
df_combo = combo_explode(df_combo)

# %%
df_gene
# Out:
#     Gene Name Combinations                                           Diseases
# 200       CPO       OLI001                          Hereditary coproporphyria
# 30       ALAD       OLI001                          Hereditary coproporphyria
# 670    NOTCH3       OLI002  Primary ovarian failure; Idiopathic pulmonary ...
# 105     BMPR2       OLI002  Pulmonary arterial hypertension; Heritable pul...
# 670    NOTCH3       OLI003  Primary ovarian failure; Idiopathic pulmonary ...
# ..        ...          ...                                                ...
# 680     NR5A1       OLI998  46,XY disorder of sex development; Syndrome wi...
# 619      MYH6       OLI998  Hypertrophic cardiomyopathy; Androgen insensit...
# 59         AR       OLI998  Amyotrophic lateral sclerosis; 46,XY disorder ...
# 934    SRD5A2       OLI999  Non-syndromic posterior hypospadias; Androgen ...
# 59         AR       OLI999  Amyotrophic lateral sclerosis; 46,XY disorder ...
#
# [3866 rows x 3 columns]

# %%
# Merge dataframes via "Combinations"
mergedf = df_gene.merge(df_disease, on="Combinations", how="left")

mergedf2 = mergedf.merge(df_combo, on="Combinations", how="left")

# %%
mergedf2.sort_values(by = 'Combinations')
# Out:
#      Gene Name Combinations  \
# 0          CPO       OLI001
# 1         ALAD       OLI001
# 2       NOTCH3       OLI002
# 3        BMPR2       OLI002
# 4       NOTCH3       OLI003
# ...        ...          ...
# 4000      MYH6       OLI998
# 4005    SRD5A2       OLI999
# 4006        AR       OLI999
# 4004    SRD5A2       OLI999
# 4007        AR       OLI999
#
#                                                Diseases ICD-10 ID  \
# 0                             Hereditary coproporphyria     E80.2
# 1                             Hereditary coproporphyria     E80.2
# 2     Primary ovarian failure; Idiopathic pulmonary ...     I27.0
# 3     Pulmonary arterial hypertension; Heritable pul...     I27.0
# 4     Primary ovarian failure; Idiopathic pulmonary ...     I27.0
# ...                                                 ...       ...
# 4000  Hypertrophic cardiomyopathy; Androgen insensit...     E34.5
# 4005  Non-syndromic posterior hypospadias; Androgen ...      N.A.
# 4006  Amyotrophic lateral sclerosis; 46,XY disorder ...     E34.5
# 4004  Non-syndromic posterior hypospadias; Androgen ...     E34.5
# 4007  Amyotrophic lateral sclerosis; 46,XY disorder ...      N.A.
#
#                 Genes
# 0           ALAD; CPO
# 1           ALAD; CPO
# 2       BMPR2; NOTCH3
# 3       BMPR2; NOTCH3
# 4       BMPR2; NOTCH3
# ...               ...
# 4000  AR; MYH6; NR5A1
# 4005       AR; SRD5A2
# 4006       AR; SRD5A2
# 4004       AR; SRD5A2
# 4007       AR; SRD5A2
#
# [4008 rows x 5 columns]

# %% [markdown]
# # Save to local file

# %%
mergedf2.to_csv('olidaexcel.csv', index=False)
